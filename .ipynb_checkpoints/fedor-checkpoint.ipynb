# %%
import pandas as pd
import jsonlines

# %%
tweets = pd.DataFrame()
created_at=[]
id=[]
full_text=[]
coordinates=[]
lang=[]
geo=[]
#hashtags=[]
with jsonlines.open('/Users/fedorkleber/Documents/Data Science/Data Systems Project/blm_1_full.jsonl') as reader:
    for obj in reader:
        created_at.append(obj['created_at'])
        id.append(obj['id'])
        full_text.append(obj['full_text'])
        coordinates.append(obj['coordinates'])
        lang.append(obj['lang'])
        geo.append(obj['geo'])

# %%
tweets['created_at'] = created_at
tweets['id'] = id
tweets['text'] = full_text
tweets['coordinates'] = coordinates
tweets['lang'] = lang
tweets['geo'] = geo
# Out:
# Error: Session cannot generate requests
# at b.executeCodeCell (/Users/fedorkleber/.vscode-insiders/extensions/ms-toolsai.jupyter-2020.12.414227025/out/client/extension.js:49:701508)
# at b.execute (/Users/fedorkleber/.vscode-insiders/extensions/ms-toolsai.jupyter-2020.12.414227025/out/client/extension.js:49:701062)
# at /Users/fedorkleber/.vscode-insiders/extensions/ms-toolsai.jupyter-2020.12.414227025/out/client/extension.js:49:697679
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:97:5)

# %%
tweets
# Out:
# ['',
#  '',
#  'She/her       Bristol, England',
#  '',
#  'United States',
#  'Mountain Home, ID',
#  'Brockport, NY',
#  '',
#  'Nigeria',
#  'SE Wisconsin',
#  'Kansas City, MO',
#  'Barranquilla, Colombia',
#  '',
#  '',
#  'Delhi',
#  '',
#  '',
#  'BKK Thailand',
#  'on my bf',
#  'lc ♡ GR',
#  '',
#  '',
#  'Dreaming',
#  'コレリア',
#  '',
#  'mystic falls',
#  '',
#  'Death Weapon Meister Academy ',
#  'Florida',
#  '',
#  'California, USA',
#  'FortsJackMonmoKnoxShaftScho',
#  '',
#  '',
#  'gen + he/they + 17',
#  'California, USA',
#  'South Africa',
#  'Nebraska',
#  'Chicago, IL',
#  'Texas, USA, Citizen of Earth',
#  'australia (she/her)',
#  '',
#  '',
#  'France',
#  'Stairway To Heaven',
#  '',
#  'Roblox ',
#  'Donde esté.',
#  'San Cristóbal. Edo. Táchira. ',
#  'Shadow Moses Island',
#  'California, USA',
#  'New York, NY',
#  'Seattle, Washington',
#  'United States',
#  'Global',
#  'Hillsborough, NJ',
#  'Beyond earth',
#  'Florida, USA',
#  'mt. p michigan ',
#  'California',
#  '九州の海と山の隙間',
#  '',
#  'Rio Grande do Sul, Brasil',
#  'International ',
#  'ÜT: 4.627714,-74.067632',
#  'Walnut Creek, CA',
#  'Kolkata, India',
#  '',
#  'Myanmar',
#  'Colombia',
#  'Texas, USA',
#  'San Diego',
#  'Waimānalo, Hawaiʻi',
#  'only in my dreams ',
#  'Portland, Oregon',
#  'Raleigh, NC',
#  '',
#  '',
#  '',
#  '',
#  'stan jodie and alycia',
#  'สู่ขิตในวันที่เหี้ย',
#  'New Delhi, India',
#  '',
#  'Pisces',
#  'She/her',
#  '',
#  '.\\//\\. 757',
#  '',
#  'wild wild west',
#  '長崎出身。 長崎に出戻り',
#  'Venezuela',
#  '',
#  '',
#  '',
#  'Alief, Houston',
#  '',
#  "N 34� 40' 0'' / W 82� 50' 0''",
#  'Nigeria',
#  'Montgomeryville, PA',
#  '21 • they/she • 222',
#  'Winter Park, FL',
#  "Where I'm suppose to be!",
#  'Atlanta',
#  'Stream Make a wish you hoes ',
#  'Iloilo City, Western Visayas',
#  'Oklahoma, USA',
#  'Raleigh, NC',
#  '',
#  'Madison, WI',
#  'Tennessee, USA',
#  'Johor Bahru, Johor',
#  'Raleigh NC',
#  '',
#  '',
#  '',
#  '',
#  'Mexico',
#  '',
#  '',
#  '',
#  'Atlanta, GA',
#  'Nigeria',
#  '',
#  'Knoxville, TN',
#  '',
#  'St Paul, MN',
#  'California, USA',
#  'Hammond, IN',
#  '',
#  "yo boyfriend's house",
#  'Puerto Rico, USA',
#  'Mayagüez, Puerto Rico',
#  'East Coast ',
#  'Mumbai | NYC',
#  '',
#  'Illinois',
#  '',
#  '',
#  'panda world',
#  '',
#  'Brazil',
#  'blacklivesmatters.carrd.co',
#  'Rio de Janeiro',
#  'California, USA',
#  '',
#  '',
#  'California ',
#  '',
#  'New York, NY',
#  'Nova Caesarea',
#  'Pacific Northwest',
#  'Whats a location',
#  '',
#  '',
#  '',
#  '',
#  'Michigan',
#  'Toronto ',
#  'United States',
#  '',
#  '',
#  '',
#  '',
#  'Powder Springs, GA',
#  'California, USA',
#  'Orchard Park, NY',
#  '',
#  'New York, NY',
#  'Jaipur, India',
#  'Corinth, Texas',
#  '',
#  '𝗨𝗣𝗛𝗦. 𝗨𝗣𝗗 𝗖𝗵𝗘. 🌈',
#  '',
#  'Medellín, Colombia',
#  'USA',
#  '',
#  '',
#  'Phoenix, AZ',
#  '',
#  'Niggas Can’ Have Shit In Yugan',
#  '',
#  '',
#  '',
#  'Stuttgart, Germany',
#  'West Coast',
#  '',
#  'United States',
#  'they/them. 21.',
#  'qanon dot pub',
#  'ur moms',
#  'Albuquerque, NM',
#  '',
#  'New York, New York',
#  '',
#  'Illinois, USA',
#  'CT.',
#  'Indianapolis, IN',
#  '',
#  'Home Team Academy ',
#  'Nigeria',
#  '',
#  '',
#  'United States',
#  'Argentina',
#  "Haunting the GOP's nightmares.",
#  'Shibuya-ku, Tokyo',
#  'California, USA',
#  '',
#  'Union City',
#  'Bengaluru, India',
#  'Carson',
#  'Las Vegas, NV',
#  '',
#  'Bengaluru, India',
#  'United States',
#  'she/her ',
#  'Los Angeles',
#  '',
#  'Philippines 🇵🇭',
#  'New York, NY',
#  'Las Vegas, NV',
#  '',
#  '',
#  'my bed',
#  '',
#  'Oui... non.',
#  '',
#  '𝓙𝓲𝓼𝓾𝓷𝓰',
#  'England, United Kingdom',
#  'United States',
#  'Cleveland, OH',
#  'Eastvale, CA',
#  '',
#  'Harrisburg, IL',
#  '',
#  '',
#  'California, USA',
#  'Boston, MA',
#  'anywhere right now',
#  'Depression mein ',
#  'Antarctica',
#  '',
#  '𐤀',
#  'Seremban, Negeri Sembilan',
#  'MINOR ! ',
#  'Texas, USA',
#  'Netherworld',
#  'Tampa, FL',
#  'Aptos, California',
#  'Roissy-en-France, France',
#  'i-Afrika',
#  'Chicago, IL',
#  '',
#  'YeonTata ❤🐶',
#  'CARACAS',
#  '',
#  '',
#  'ex cp2 tjk',
#  'мσσи',
#  '日本 埼玉',
#  'paulista  ',
#  'Riyadh, Kingdom of Saudi Arabi',
#  'FL',
#  'Conroe, TX',
#  'Woodstock, IL',
#  '',
#  'around the world',
#  '',
#  'San Diego',
#  'Edmonton, Alberta',
#  'Olympia, WA',
#  '',
#  'Arizona, USA',
#  '',
#  'MoonStar',
#  '',
#  '',
#  'Nashville',
#  'Cagayan De Oro City',
#  'armação dos Búzios',
#  'Ottawa, Ontario',
#  'Long Beach, CA',
#  '',
#  '黄昏の日本',
#  'Middle Georgia USA',
#  '',
#  '',
#  'Carson City, NV',
#  'Dinuba, CA',
#  '',
#  '',
#  'State College, PA',
#  '',
#  'TX',
#  'Miami, FL',
#  '',
#  'Waco, TX',
#  'shrieker island',
#  'So-Called North America',
#  'Brasil',
#  'Caguas, Puerto Rico',
#  'Santa Rosa, Brasil',
#  'KY',
#  '',
#  'Georgia',
#  'San Diego, CA',
#  '',
#  'Maracay-Venezuela',
#  'Ventura, CA',
#  '𐤀',
#  '',
#  'Socal',
#  'Australia',
#  '',
#  '',
#  'Bay Area, CA',
#  '',
#  'United States',
#  'Banning  CA',
#  'Arizona',
#  '',
#  'Idaho, USA',
#  '',
#  'NE PDX, OR',
#  '',
#  'กาแลคซี่บิกฮิต',
#  'United States',
#  'Earth',
#  '',
#  'India',
#  '',
#  'Boise, ID',
#  '',
#  'United States',
#  'Colombia',
#  '',
#  'depression',
#  'UNC Brinkhous-Bullit Morgue',
#  'she/her',
#  '',
#  'Toronto, Ontario',
#  'aurora',
#  'Worldwide',
#  '',
#  'Pittsburgh, PA',
#  '',
#  'she/her',
#  'stan blathers ',
#  'Kansas City, MO',
#  'Israel',
#  '',
#  'ป๋อจ้านไม่สลับโพ ',
#  '아포방포💞',
#  '',
#  'Los Angeles',
#  'In your heart',
#  'AZ',
#  '',
#  'North Las Vegas, NV',
#  'Argentina',
#  '',
#  'Medellín, Colombia',
#  'Michigan',
#  'NZ',
#  '',
#  '',
#  'San Diego, CA',
#  '',
#  'Nashville, TN',
#  'Portland',
#  '90069',
#  '7-11 taquito rack',
#  '',
#  '',
#  '',
#  'Yreka, CA',
#  'NYC/Brooklyn native',
#  'New York City',
#  'Quito-Ecuador',
#  'Philadelphia, PA',
#  '',
#  '',
#  'Concordia, Elpis',
#  'Mayagüez, Puerto Rico',
#  'Wakanda land ',
#  'Aloha as of late',
#  'OffTheHooks',
#  '',
#  'Austin, TX',
#  'Lewisham, London',
#  'online!',
#  'Rio de Janeiro, Brasil',
#  'Someone Lost Along The Way',
#  '',
#  '',
#  'Red State USA',
#  'Texas, USA',
#  '',
#  'she/her',
#  'Dallas',
#  'Chicago, IL ',
#  'Jersey :)',
#  'New Orleans',
#  'Toronto, Ontario',
#  '',
#  'Western New York',
#  'United States',
#  'Chasing the ice cream truck',
#  '',
#  '',
#  '',
#  'St Louis, MO',
#  'VA',
#  'Texas ',
#  'Los Angeles, CA',
#  'Raleigh, USA',
#  '',
#  'USA',
#  '',
#  'San Diego, CA',
#  '',
#  'Acampamento Jupiter',
#  '',
#  '',
#  'Texas, USA',
#  'she/her',
#  'New York, NY',
#  'Penha, Brasil',
#  'RT not endorsements. ',
#  'Schenectady, NY',
#  'United States',
#  '',
#  'San Antonio, Texas',
#  '5/5 YAYAS • SL • LV • HTX ',
#  '',
#  '',
#  '',
#  'St Louis, MO',
#  '',
#  'Phoenix, AZ',
#  'Lima, OH',
#  'Detroit, MI',
#  '',
#  '',
#  'Portland, OR',
#  '#SanCristóbalEstadoTáchiraVzla',
#  '',
#  '',
#  'Salt Lake City, UT',
#  'New York, NY',
#  '',
#  'Dreaming..// moonkitten',
#  '대한민국 청주시',
#  '',
#  'Moore, OK',
#  'DeKalb, IL',
#  '',
#  'califas y zacatecas',
#  'Everywhere',
#  'nyc',
#  '',
#  '',
#  '',
#  '',
#  'Paris, TX',
#  '',
#  '',
#  '',
#  'in a state of Gracemere',
#  'The Colony, TX',
#  'Dallas, TX',
#  'ARA',
#  '',
#  '',
#  'El Paso, TX',
#  'Australia',
#  'Chicago, IL',
#  '',
#  '',
#  'San Antonio, TX she/her',
#  'Texas, USA',
#  'AT THE MOVIES',
#  'Vancouver, British Columbia',
#  'defund the police',
#  '',
#  '',
#  'California, USA',
#  '',
#  'Ottawa, Ontario',
#  'Lansing,mi.',
#  'Chicago, Illinois',
#  'Israel',
#  'Oracle Park 🧡🖤🧡🖤🧡🖤',
#  '',
#  'Sydney, New South Wales',
#  '',
#  'United States',
#  'Florida, USA',
#  'Kauai',
#  '',
#  'Lima, Peru',
#  'Manda busca!',
#  'Mississippi, USA',
#  'Sicilia, Italia',
#  '70001',
#  'slc they/her',
#  'Oakland, CA',
#  '',
#  'TX/MN',
#  'المملكة العربية السعودية',
#  '',
#  'Canada',
#  '',
#  'Nashville, TN',
#  'Between Realities, Brooklyn',
#  'stargazing with jimin.♡',
#  'Indiana, USA',
#  'Downingtown, PA',
#  '19 | she/her | 🇨🇦',
#  'Portland, OR',
#  'TERRE',
#  '',
#  'California, USA',
#  '',
#  'VA',
#  'twiggs county',
#  'Between Uranus & Saturn',
#  'Los Angeles',
#  '',
#  '',
#  '',
#  'Miami, FL',
#  '',
#  '',
#  '',
#  'The Destiel Glory Hole, Kansas',
#  'San Diego, CA',
#  '',
#  '',
#  'Detroit, MI (metro)',
#  'United States',
#  'Berkeley, CA',
#  ' ❍ She/Her ❍ + ❐ rt heavy ❐',
#  '',
#  'UK citizen of the world',
#  'Dallas, TX',
#  '',
#  'Something, Somewhere',
#  'Chiba, Japan',
#  '',
#  'Louisville, KY',
#  'germany',
#  'Nevada, USA',
#  'IG: shvetathakrar',
#  'Sydney',
#  'Milwaukee, WI',
#  '',
#  '',
#  'Surat, India',
#  '',
#  'San Diego, CA',
#  'Brooklyn, NY',
#  'San Antonio, TX',
#  '',
#  'Tennessee',
#  "N-city, Johnny's heart ",
#  'Peaceful country PAKISTAN 🇵🇰',
#  'New York, USA',
#  'Oregon, USA',
#  '',
#  'Surrey, British Columbia',
#  'Analyzing the World',
#  'Washington, USA',
#  'Hollywood, Los Angeles',
#  '',
#  '',
#  'The Homefront',
#  '',
#  'NA',
#  'Staten Island, NY',
#  '',
#  'Washington, DC',
#  '',
#  '',
#  'Phenix City, AL',
#  'Williston Park, NY',
#  '',
#  '',
#  'nct rvv',
#  'Vancouver BC Canada',
#  '',
#  '日本 東京',
#  '22 she/her',
#  'purgatoiré ; Les mondialé',
#  'on a plane',
#  '',
#  '',
#  '',
#  '',
#  'Red State',
#  '',
#  '',
#  'USa',
#  '',
#  '',
#  'Rosario',
#  'Bowie State Univ.',
#  'Denver, CO',
#  'Belém, Brasil',
#  'Australia',
#  '',
#  'Anaheim, CA',
#  'She/her',
#  'Carlsbad, CA',
#  'Fort Worth, TX',
#  'Mariana Trench ',
#  'Nashville, TN',
#  '',
#  'world.universe',
#  'ประเทศไทย',
#  'Kansas, USA',
#  '',
#  'Santiago, Chile',
#  'Scottsdale, Arizonaaa',
#  '',
#  'New York, NY',
#  '',
#  'honeymoon âve',
#  '',
#  '𝒽𝒶𝓎𝒾',
#  '',
#  '',
#  'Central, VA',
#  'United States',
#  '🇵🇪',
#  '',
#  '#PA01 Bucks County #PAResists ',
#  '',
#  '',
#  'Washington, DC',
#  '',
#  'She/her Camp Unus Annus',
#  '',
#  '🌸 ',
#  'Oakland, CA',
#  'they/them',
#  'Nov. 3rd 🇺🇸 will be heard!',
#  'Literally, A Loser',
#  'The Capital, Kuwait',
#  '',
#  'Goshute/Shosone/Ute land ',
#  'Flavortown, USA',
#  'Austin, TX',
#  '',
#  'Los Angeles, CA',
#  '',
#  'Schriever, LA',
#  'ramaytush ohlone land - SF',
#  '',
#  '',
#  '',
#  '',
#  'Toronto',
#  'Norman, OK',
#  'South London',
#  'USA',
#  '',
#  'taekook 050520',
#  'Waco, TX',
#  'Toronto, Ontario',
#  'slc',
#  'Los Angeles, CA',
#  'Gulf Coast of Alabama',
#  '',
#  '',
#  '',
#  'IKA•ATH•APF•DCA•LAX•LAS•DCA',
#  '',
#  'The World May Never Know',
#  'Andover, Hampshire',
#  '',
#  'bts world',
#  'WV, STL, Gujarat, Columbus',
#  'j g m ',
#  'Houston, TX',
#  '',
#  'San Diego, CA',
#  '',
#  'Calgary, Alberta',
#  '',
#  '',
#  '',
#  'Dark Side Of The Moon',
#  'stolen land with stolen people',
#  '',
#  '',
#  'fxbg, va',
#  '',
#  'Victoria, TX',
#  'she/her/siya',
#  '',
#  'Naples, Florida',
#  '4:13',
#  'Home ',
#  'Earth',
#  'Brooklyn, NY',
#  'a garbage can, KS',
#  '',
#  '',
#  'Toronto, Ontario',
#  'venus ',
#  'Eden Monaro NSW',
#  'Atlanta, GA',
#  'STL',
#  'Seattle, WA',
#  'California ',
#  'Minnesota',
#  'Fuck you. ',
#  'California',
#  'United States',
#  'Brooklyn, NY',
#  'Canada',
#  '',
#  'New York, NY',
#  '',
#  'California, USA',
#  'Lynnwood, WA',
#  'Mumbai',
#  '',
#  '',
#  'Florida',
#  '',
#  'Onesie-ing around somewhere...',
#  'Middle Earth',
#  'Unceded Lenape land & Taiwan',
#  '',
#  'Not sure but we out here doe',
#  'Mombasa, Kenya',
#  '18',
#  'NJ  / NY',
#  'Tiruchengode@Tamil Nadu ',
#  'Ohio',
#  'Highland, CA',
#  'Johor Bahru, Johor',
#  '',
#  '',
#  'Olympia, WA',
#  'magic shop',
#  '',
#  'Quezon City, National Capital',
#  'Boston, MA',
#  'she, her | 21',
#  '',
#  'Toronto, Ontario',
#  'The United States of America',
#  '',
#  'New Brunswick, Canada',
#  'Chicago, IL',
#  'San Antonio, TX',
#  'San Jose',
#  'chicago',
#  'ÜT: 34.12683,-117.42904',
#  '',
#  'Chicago, IL',
#  'Nightvale',
#  'Arizona, USA',
#  '日本 北海道',
#  '',
#  ' california',
#  'Perth, Western Australia',
#  'Hell',
#  'Eagle, ID',
#  'TEXAS',
#  'خیالوں میں ',
#  'Coronel Belisle',
#  '',
#  '',
#  'Here, there, everywhere. :)',
#  'Ontario, Canada',
#  '',
#  'Slander set',
#  '',
#  '',
#  'Toronto, Ontario',
#  '',
#  'NJ',
#  'Houston, Texas ',
#  'England, UK.',
#  'they/she',
#  'Earth',
#  'Iceland',
#  'SF, LA',
#  '',
#  'Cambridge',
#  'Hepburn Springs',
#  'New York, USA',
#  'BLM 1312',
#  '',
#  'd1ce + ggs',
#  '',
#  '',
#  '☀️He/They!🌻',
#  '',
#  'he/they',
#  'Bogotá, Colombia. ',
#  '',
#  'kait ✧･ﾟ*',
#  '',
#  'Charlotte, NC',
#  '',
#  '',
#  'Rimini',
#  '',
#  '',
#  'nova / rva',
#  'Montreal, QC',
#  '',
#  'Shadow Mountains, USA',
#  'OKAGA, CA',
#  'DMV',
#  '',
#  'Ｎ型（いぬがた）県 シャドウ・シティ',
#  '',
#  'Chattanooga, TN',
#  'Saarland',
#  'Bikini Bottom',
#  '',
#  '',
#  'Oakland, CA',
#  'non-dating',
#  '',
#  'California, USA',
#  '',
#  'New Delhi, India',
#  '',
#  'Los Angeles, CA',
#  '',
#  '',
#  'Nashville, TN',
#  'Rebolusyon ang solusyon',
#  'HYrule',
#  'Tacoma, WA',
#  'United States',
#  'South Beach',
#  '',
#  'Los Angeles',
#  'Houston, TX',
#  'Maryland, USA',
#  'California, USA',
#  '',
#  '',
#  '',
#  'Mother Earth ',
#  'veracruz',
#  'Adelaide, South Australia',
#  '',
#  'bay area',
#  '',
#  'Saraland, AL',
#  'HOU|SA',
#  'Misiones, Argentina',
#  'Chile',
#  'United States',
#  'montreal, qc',
#  '',
#  'Purgatory',
#  'Planet Trishanku',
#  'Granger, IN',
#  '',
#  '',
#  '',
#  'Valparaíso, Chile',
#  'jundiaí, sp',
#  '',
#  'Haiti • connecticut ',
#  '',
#  'Fort Lauderdale, FL',
#  'Q8',
#  '2226 Strawberry Rd. ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  's/h',
#  'Redding, CA',
#  '',
#  'Los Angeles, CA',
#  'Pittsburgh, PA',
#  'General Zuazua, Nuevo León',
#  'El Lay! City of Lost Angels!',
#  '',
#  '',
#  'Johor Bahru, Johor',
#  'sir, I’m from the internet',
#  '',
#  '',
#  'Massachusetts, USA',
#  '',
#  'Venezuela',
#  'Your mothers patio',
#  'USA',
#  '',
#  'Black Lives Matter',
#  'El Paso, TX',
#  'Texas, USA',
#  '',
#  'Louisville · Terre Haute ',
#  '',
#  '',
#  'Top Right, US',
#  '',
#  '',
#  'DMV ➡️ ATL',
#  'Lekki, Nigeria ',
#  '. TEXAS ',
#  'Kuşadası, Türkiye',
#  'Hawaii, USA',
#  'Montréal, Québec',
#  'fl ',
#  'Good Jesus From Itabapoana',
#  '',
#  'Texas',
#  '',
#  '',
#  '',
#  'กรุงเทพมหานคร, ประเทศไทย',
#  'Valencia, España',
#  '',
#  'Hope World',
#  '',
#  '',
#  'Seattle, WA',
#  'England, United Kingdom',
#  'Brooklyn, NY',
#  '',
#  '',
#  '',
#  '',
#  'South Korea - Seoul',
#  'NC',
#  'San Francisco Bay Area, CA',
#  'Colorado, USA',
#  'Atlanta, GA',
#  'CHI-TOWN ✮TX LU√✮ ',
#  'Liverpool ➡️ ATL ',
#  'Brooklyn, NY',
#  'Under the Bridge',
#  'Washington, USA',
#  '中野区',
#  'Harrisburg, PA',
#  'Perth, Western Australia',
#  '',
#  'Portland, OR',
#  '',
#  'Atlanta, GA',
#  '✞ᶜʳᵘᶜᵉˢ✞',
#  'mi🦀',
#  '',
#  'Houston, TX',
#  '',
#  '',
#  '',
#  'Indianapolis, IN',
#  'AUSTRALIA',
#  'Nigeria',
#  'Bay Area',
#  '',
#  'MI VENEZUELA AMADA',
#  'Texas, USA',
#  'Madhouse Earth',
#  'Arkansas, USA',
#  '',
#  'Winchester',
#  '',
#  '',
#  "RT's, follows, likes do not = endorsement. Lists will be blocked.",
#  'Argentina ',
#  'United States',
#  'United States',
#  '',
#  'Whole world',
#  'Maryland, USA',
#  's fl',
#  'New York/Paris/Megéve/Berlin',
#  'Canada',
#  'BeGreat',
#  'México Lindo ',
#  ' USA',
#  'Bagan Serai, Perak',
#  'Virginia',
#  'Austin, TX',
#  'Hell Itself',
#  'Queens, NY',
#  'Detroit, MI',
#  '',
#  'Tokyo ',
#  'she, her',
#  ...]

# %%
bool_series = pd.notnull(tweets['coordinates'])
tweets = tweets[bool_series]
tweets.to_json('BLM_1.json')

# %%
def clean_hyperlinks(text): 
    result = re.sub(r'https?://[^\s<>"]+|www\.[^\s<>"]+'," ", text)
    return result

# %%
print(len(tweets))
tweets2 = tweets
# Out:
# 533706

# %%
tweets = tweets[tweets['lang'] == 'en']
tweets['text'] = tweets['text'].apply(clean_hyperlinks)
tweets['text'].replace('', np.nan, inplace=True)
tweets.dropna(subset=['text'], inplace=True)

# %%
def string_manipulation(df,column): 
    #extract hashtags
    df["hashtag"]  = df[column].str.findall(r'#.*?(?=\s|$)')
    #extract twitter account references
    df["accounts"] = df[column].str.findall(r'@.*?(?=\s|$)')
    return df

# %%
tweets = string_manipulation(tweets,"text")

# %%
tweets['hashtag'] = tweets['hashtag'].apply(lambda x: ','.join(map(str, x)))

# %%
from string import punctuation
def punctation(text): 
    result = text.replace("#", "")
    result = result.lower()
    return result
tweets['hashtag'] = tweets['hashtag'].apply(punctation)

# %%
def inlist(text): 
    result = text.split(",")
    return result
tweets['hashtag'] = tweets['hashtag'].apply(inlist)

# %%
list_of_tweets = []
for tweet in tweets['text']:
    temp = tweet
    list_of_tweets.append(temp)

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

# Create a set of stopwords
stop = set(stopwords.words('english'))

# Create a set of punctuation words 
exclude = set(string.punctuation) 

# This is the function makeing the lemmatization
lemma = WordNetLemmatizer()

# In this function we perform the entire cleaning
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

# This is the clean corpus.
doc_clean = [clean(doc).split() for doc in list_of_tweets] 
tweets['token'] = doc_clean

# %%
tweets.tail(50)
# Out:
#                             created_at                  id  \
# 533651  Sat Jan 03 15:38:53 +0000 2015  551402323918860288
# 533652  Sat Jan 03 15:38:59 +0000 2015  551402351614255104
# 533653  Sat Jan 03 15:39:17 +0000 2015  551402426150813696
# 533654  Sat Jan 03 15:39:57 +0000 2015  551402594502209536
# 533655  Sat Jan 03 15:40:00 +0000 2015  551402604266545152
# 533656  Sat Jan 03 15:40:11 +0000 2015  551402653113397249
# 533657  Sat Jan 03 15:40:21 +0000 2015  551402692091080704
# 533658  Sat Jan 03 15:40:35 +0000 2015  551402752623271937
# 533659  Sat Jan 03 15:40:37 +0000 2015  551402762161102848
# 533660  Sat Jan 03 15:41:05 +0000 2015  551402880503386112
# 533661  Sat Jan 03 15:41:58 +0000 2015  551403100531998720
# 533662  Sat Jan 03 15:41:59 +0000 2015  551403104826970112
# 533663  Sat Jan 03 15:42:13 +0000 2015  551403162742300672
# 533664  Sat Jan 03 15:42:24 +0000 2015  551403209030258688
# 533665  Sat Jan 03 15:42:26 +0000 2015  551403219855765505
# 533666  Sat Jan 03 15:42:42 +0000 2015  551403287405019136
# 533668  Sat Jan 03 15:43:19 +0000 2015  551403438656212993
# 533669  Sat Jan 03 15:43:41 +0000 2015  551403533593874433
# 533670  Sat Jan 03 15:43:58 +0000 2015  551403606092824578
# 533671  Sat Jan 03 15:44:32 +0000 2015  551403748862357504
# 533672  Sat Jan 03 15:44:37 +0000 2015  551403767480860672
# 533673  Sat Jan 03 15:45:41 +0000 2015  551404034482266113
# 533674  Sat Jan 03 15:45:48 +0000 2015  551404066086338560
# 533677  Sat Jan 03 15:46:42 +0000 2015  551404290473201664
# 533678  Sat Jan 03 15:46:47 +0000 2015  551404314481393665
# 533679  Sat Jan 03 15:47:25 +0000 2015  551404472153296896
# 533680  Sat Jan 03 15:47:36 +0000 2015  551404519045599232
# 533681  Sat Jan 03 15:47:37 +0000 2015  551404521801666561
# 533682  Sat Jan 03 15:47:39 +0000 2015  551404529690750976
# 533683  Sat Jan 03 15:47:57 +0000 2015  551404605201215489
# 533684  Sat Jan 03 15:48:36 +0000 2015  551404771970928640
# 533685  Sat Jan 03 15:49:23 +0000 2015  551404969287376896
# 533686  Sat Jan 03 15:50:01 +0000 2015  551405128369319936
# 533687  Sat Jan 03 15:50:02 +0000 2015  551405129786986496
# 533688  Sat Jan 03 15:50:53 +0000 2015  551405343775793153
# 533690  Sat Jan 03 15:52:58 +0000 2015  551405868043231233
# 533691  Sat Jan 03 15:57:47 +0000 2015  551407079681183744
# 533692  Sat Jan 03 15:58:18 +0000 2015  551407209708417024
# 533693  Sat Jan 03 15:58:53 +0000 2015  551407357373067265
# 533694  Sat Jan 03 15:58:56 +0000 2015  551407369356603392
# 533695  Sat Jan 03 15:58:56 +0000 2015  551407369456873472
# 533696  Sat Jan 03 15:59:42 +0000 2015  551407562483314688
# 533697  Sat Jan 03 16:01:06 +0000 2015  551407917195616256
# 533698  Sat Jan 03 16:02:14 +0000 2015  551408202349178881
# 533699  Sat Jan 03 16:03:18 +0000 2015  551408471451893760
# 533700  Sat Jan 03 16:03:42 +0000 2015  551408572400427009
# 533701  Sat Jan 03 16:04:21 +0000 2015  551408735646937089
# 533703  Sat Jan 03 16:07:34 +0000 2015  551409544069271552
# 533704  Sat Jan 03 16:08:25 +0000 2015  551409757912055808
# 533705  Sat Jan 03 16:10:09 +0000 2015  551410191548166144
#
#                                                      text  \
# 533651  I try not to take it personally when u condemn...
# 533652  WATCH Black People's Grand Jury on #MikeBrown ...
# 533653  @TheVikChick 1/9 #ATL Plz Watch/RETWEET   #bla...
# 533654  Mother's Moving Sign Why She Protests At Fox N...
# 533655        John Nantz - #AllLivesMatter? Not So Much
# 533656                   #blacklivesmatter Damon Turner
# 533657                  2 cops killed #BlackLivesMatter
# 533658  Policy Changes the Anti-#PoliceViolence Moveme...
# 533659  @Shelbypitt8Pitt @JenLLM I wish we had the mea...
# 533660  Be extremely subtle, even to the point of form...
# 533661  Join the #movement We ain't gonna stop til peo...
# 533662  Bill Introduced To Ban #Protesters From Wearin...
# 533663  #research started watching cop movies\n&amp; r...
# 533664  'Sun Is Still Out and Everything' After Arrest...
# 533665  #MayorDeBlasio RESIGN, NOT Fit toLead,Anti-Pol...
# 533666  Remember the queer feminist 'Herstory of the #...
# 533668  @Shelbypitt8Pitt @JenLLM It appears that way t...
# 533669  "Until #AllLivesMatter there are no truths in ...
# 533670  #AllLivesMatter includes everyone. White, blac...
# 533671  Oprah Says #BlackLivesMatter Protests Lack ‘Le...
# 533672  One of #AlSharpton MayordeBlasio,#Obama's Left...
# 533673            #BlackLivesMatter Family is Essential
# 533674  #AllLivesMatter and tbh\n#BlackLivesMatter mor...
# 533677  John Nantz - #AllLivesMatter? Not So Much   #B...
# 533678  “@nytimes: No Turned Backs at Officer Liu’s Fu...
# 533679  Tomorrow's #BlackLivesMatter protest in Israel...
# 533680  Do police have a death wish for black men?  Ex...
# 533681  @Oprah:"the movement needs leaders"   protesto...
# 533682  RESIGN NOW! #MayordeBlasio! #AlSharpton #Black...
# 533683  @Shelbypitt8Pitt @JenLLM ... would have never ...
# 533684  #BlackLivesMatter You were created to be loved!
# 533685  Can't Stop, Won't Stop: #BlackLivesMatter Move...
# 533686  All Lives Matter God show yourself strong RT @...
# 533687  All Lives Matter God show yourself strong RT @...
# 533688  Oprah Says #BlackLivesMatter Protests Lack ‘Le...
# 533690                  \n#AllLivesMatter \nPlz rt peeps!
# 533691  #Bless Someone Today!\n#Love #Blessings #Chris...
# 533692  I added a video to a @YouTube playlist   #NYE2...
# 533693  I added a video to a @YouTube playlist   #NYE2...
# 533694  I added a video to a @YouTube playlist   #NYE2...
# 533695  I added a video to a @YouTube playlist   #NYE2...
# 533696  A moment of growth...\n\nWhen you stop caring ...
# 533697  @wizdom4you Luv your tweets! Please keep them ...
# 533698  2015 new year same struggle #BlackLivesMatter \n
# 533699  @JDGEXMMG Mr - 27 Welcome - To - My - City by ...
# 533700  @SrNaturalista @AnonCrips @FoxNews @umojasasa ...
# 533701  @GrumpyMrRedNeck One of the positives coming o...
# 533703  Tell SFBart to drop the $70k fine for BlackLiv...
# 533704  @JoeNBC #BlackLivesMatter when it comes to rat...
# 533705  @ABGray 1/9 #ATL Plz Watch/RETWEET   #blackliv...
#
#                                               coordinates lang  \
# 533651                                               None   en
# 533652                                               None   en
# 533653                                               None   en
# 533654                                               None   en
# 533655                                               None   en
# 533656                                               None   en
# 533657                                               None   en
# 533658                                               None   en
# 533659                                               None   en
# 533660                                               None   en
# 533661                                               None   en
# 533662                                               None   en
# 533663                                               None   en
# 533664                                               None   en
# 533665                                               None   en
# 533666                                               None   en
# 533668                                               None   en
# 533669                                               None   en
# 533670                                               None   en
# 533671                                               None   en
# 533672                                               None   en
# 533673                                               None   en
# 533674                                               None   en
# 533677                                               None   en
# 533678                                               None   en
# 533679                                               None   en
# 533680                                               None   en
# 533681  {'type': 'Point', 'coordinates': [-17.5055061,...   en
# 533682                                               None   en
# 533683                                               None   en
# 533684                                               None   en
# 533685                                               None   en
# 533686                                               None   en
# 533687                                               None   en
# 533688                                               None   en
# 533690                                               None   en
# 533691                                               None   en
# 533692                                               None   en
# 533693                                               None   en
# 533694                                               None   en
# 533695                                               None   en
# 533696                                               None   en
# 533697                                               None   en
# 533698                                               None   en
# 533699                                               None   en
# 533700                                               None   en
# 533701                                               None   en
# 533703                                               None   en
# 533704                                               None   en
# 533705                                               None   en
#
#                                                       geo  \
# 533651                                               None
# 533652                                               None
# 533653                                               None
# 533654                                               None
# 533655                                               None
# 533656                                               None
# 533657                                               None
# 533658                                               None
# 533659                                               None
# 533660                                               None
# 533661                                               None
# 533662                                               None
# 533663                                               None
# 533664                                               None
# 533665                                               None
# 533666                                               None
# 533668                                               None
# 533669                                               None
# 533670                                               None
# 533671                                               None
# 533672                                               None
# 533673                                               None
# 533674                                               None
# 533677                                               None
# 533678                                               None
# 533679                                               None
# 533680                                               None
# 533681  {'type': 'Point', 'coordinates': [14.74835449,...
# 533682                                               None
# 533683                                               None
# 533684                                               None
# 533685                                               None
# 533686                                               None
# 533687                                               None
# 533688                                               None
# 533690                                               None
# 533691                                               None
# 533692                                               None
# 533693                                               None
# 533694                                               None
# 533695                                               None
# 533696                                               None
# 533697                                               None
# 533698                                               None
# 533699                                               None
# 533700                                               None
# 533701                                               None
# 533703                                               None
# 533704                                               None
# 533705                                               None
#
#                                                   hashtag  \
# 533651               [blacklivesmatter, whitelivesmatter]
# 533652  [mikebrown, ferguson, blacktwitter, blacklives...
# 533653                            [atl, blacklivesmatter]
# 533654                   [icantbreathe, blacklivesmatter]
# 533655                                  [alllivesmatter?]
# 533656                                 [blacklivesmatter]
# 533657                                 [blacklivesmatter]
# 533658       [policeviolence, blacklivesmatter, politics]
# 533659                                 [blacklivesmatter]
# 533660                            [blacklivesmatter, aow]
# 533661  [movement, tamirrice, johncrawford, blacklives...
# 533662  [protesters, hoodies, oklahoma, protests, occu...
# 533663                       [research, blacklivesmatter]
# 533664              [blacklivesmatter, policelivesmatter]
# 533665  [mayordeblasio, alsharton, nypd, blacklivesmat...
# 533666                                 [blacklivesmatter]
# 533668                                 [blacklivesmatter]
# 533669                                   [alllivesmatter]
# 533670                          [alllivesmatter, prolife]
# 533671                                 [blacklivesmatter]
# 533672  [alsharpton, obama's, blacklivesmatter, nypd, ...
# 533673                                 [blacklivesmatter]
# 533674                 [alllivesmatter, blacklivesmatter]
# 533677                 [alllivesmatter?, bluelivesmatter]
# 533678                                  [bluelivesmatter]
# 533679               [blacklivesmatter, strikeforfreedom]
# 533680            [unctv, blacklivesmatter, icantbreathe]
# 533681                                 [blacklivesmatter]
# 533682  [mayordeblasio!, alsharpton, blacklivesmatter,...
# 533683                                 [blacklivesmatter]
# 533684                                 [blacklivesmatter]
# 533685                                 [blacklivesmatter]
# 533686                                                 []
# 533687                                                 []
# 533688                                 [blacklivesmatter]
# 533690                                   [alllivesmatter]
# 533691  [bless, love, blessings, christian, humanity, ...
# 533692  [nye2015, happysa2015, happynewyeareverybody, ...
# 533693  [nye2015, happysa2015, happynewyeareverybody, ...
# 533694  [nye2015, happysa2015, happynewyeareverybody, ...
# 533695  [nye2015, happysa2015, happynewyeareverybody, ...
# 533696                                 [blacklivesmatter]
# 533697                                 [blacklivesmatter]
# 533698                                 [blacklivesmatter]
# 533699  [soundcloud, indiemusic, blacklivesmatter, bla...
# 533700                                 [blacklivesmatter]
# 533701                                 [blacklivesmatter]
# 533703                                                 []
# 533704                                 [blacklivesmatter]
# 533705                            [atl, blacklivesmatter]
#
#                                                  accounts  \
# 533651                                                 []
# 533652                                                 []
# 533653                                     [@TheVikChick]
# 533654                                        [@AshAgony]
# 533655                                                 []
# 533656                                                 []
# 533657                                                 []
# 533658                                       [@DMcKinson]
# 533659                        [@Shelbypitt8Pitt, @JenLLM]
# 533660                                                 []
# 533661                                         [@youtube]
# 533662                                                 []
# 533663                                                 []
# 533664                                                 []
# 533665                                                 []
# 533666                                                 []
# 533668                        [@Shelbypitt8Pitt, @JenLLM]
# 533669                  [@MayorLandrieu,, @NOLA_FOR_LIFE]
# 533670                                                 []
# 533671                                                 []
# 533672                                                 []
# 533673                                                 []
# 533674                                                 []
# 533677   [@BradThor, @SheriffClarke, @BoDietl, @dbongino]
# 533678                                        [@nytimes:]
# 533679                                                 []
# 533680                                                 []
# 533681                                      [@Oprah:"the]
# 533682                                                 []
# 533683                        [@Shelbypitt8Pitt, @JenLLM]
# 533684                                                 []
# 533685                                                 []
# 533686                                     [@ptfuller76:]
# 533687                                     [@ptfuller76:]
# 533688                                                 []
# 533690                                                 []
# 533691                                                 []
# 533692                                         [@YouTube]
# 533693                                         [@YouTube]
# 533694                                         [@YouTube]
# 533695                                         [@YouTube]
# 533696                                                 []
# 533697                                      [@wizdom4you]
# 533698                                                 []
# 533699                                        [@JDGEXMMG]
# 533700  [@SrNaturalista, @AnonCrips, @FoxNews, @umojas...
# 533701                         [@GrumpyMrRedNeck, @deray]
# 533703                                                 []
# 533704                                          [@JoeNBC]
# 533705                                          [@ABGray]
#
#                                                     token
# 533651  [try, take, personally, u, condemn, white, pol...
# 533652  [watch, black, people, grand, jury, mikebrown,...
# 533653  [thevikchick, 19, atl, plz, watchretweet, blac...
# 533654  [mother, moving, sign, protest, fox, newsnewsc...
# 533655                [john, nantz, alllivesmatter, much]
# 533656                  [blacklivesmatter, damon, turner]
# 533657                 [2, cop, killed, blacklivesmatter]
# 533658  [policy, change, antipoliceviolence, movement,...
# 533659  [shelbypitt8pitt, jenllm, wish, mean, help, ex...
# 533660  [extremely, subtle, even, point, formlessness,...
# 533661  [join, movement, aint, gonna, stop, til, peopl...
# 533662  [bill, introduced, ban, protester, wearing, ho...
# 533663  [research, started, watching, cop, movie, amp,...
# 533664  [sun, still, everything, arrest, drop, twothir...
# 533665  [mayordeblasio, resign, fit, toleadantipolicep...
# 533666  [remember, queer, feminist, herstory, blackliv...
# 533668  [shelbypitt8pitt, jenllm, appears, way, u, wri...
# 533669  [until, alllivesmatter, truth, country, hold, ...
# 533670  [alllivesmatter, includes, everyone, white, bl...
# 533671  [oprah, say, blacklivesmatter, protest, lack, ...
# 533672  [one, alsharpton, mayordeblasioobamas, leftist...
# 533673              [blacklivesmatter, family, essential]
# 533674  [alllivesmatter, tbh, blacklivesmatter, recogn...
# 533677  [john, nantz, alllivesmatter, much, bluelivesm...
# 533678  [“nytimes, turned, back, officer, liu’s, funer...
# 533679  [tomorrow, blacklivesmatter, protest, israel, ...
# 533680  [police, death, wish, black, men, expert, disc...
# 533681  [oprahthe, movement, need, leader, protestorsk...
# 533682  [resign, now, mayordeblasio, alsharpton, black...
# 533683  [shelbypitt8pitt, jenllm, would, never, though...
# 533684                 [blacklivesmatter, created, loved]
# 533685  [cant, stop, stop, blacklivesmatter, movement,...
# 533686  [life, matter, god, show, strong, rt, ptfuller...
# 533687  [life, matter, god, show, strong, rt, ptfuller...
# 533688  [oprah, say, blacklivesmatter, protest, lack, ...
# 533690                    [alllivesmatter, plz, rt, peep]
# 533691  [bless, someone, today, love, blessing, christ...
# 533692  [added, video, youtube, playlist, nye2015, hap...
# 533693  [added, video, youtube, playlist, nye2015, hap...
# 533694  [added, video, youtube, playlist, nye2015, hap...
# 533695  [added, video, youtube, playlist, nye2015, hap...
# 533696  [moment, growth, stop, caring, system, oppress...
# 533697  [wizdom4you, luv, tweet, please, keep, coming,...
# 533698      [2015, new, year, struggle, blacklivesmatter]
# 533699  [jdgexmmg, mr, 27, welcome, city, mr27, via, s...
# 533700  [srnaturalista, anoncrips, foxnews, umojasasa,...
# 533701  [grumpymrredneck, one, positive, coming, black...
# 533703  [tell, sfbart, drop, 70k, fine, blacklivesmatt...
# 533704      [joenbc, blacklivesmatter, come, rating, too]
# 533705  [abgray, 19, atl, plz, watchretweet, blacklive...

# %%
temp = tweets[tweets['geo'] == None]
len(temp)
#print(tweets['geo'][1])
# Out:
# 0

# %%
count = 0
for i in tweets['geo']:
    if type(tweet) == type:
        count = count+1
print(count)
# Out:
# 0

# %%
type(type(tweets['geo'][533681]))
# Out:
# type

# %%
print(count)
# Out:
# 0

# %%
tweets.to_json('tweets_BLM.json')
