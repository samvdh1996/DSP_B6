# %%
import pandas as pd
import json

# %%
f = open('BLM_2.json',) 
data = json.load(f) 
type(data)
# Out:
# dict

# %%
len(data)
coordinates = []

#print(data['geo'])
for i in data['geo'].values():
        #print(i['coordinates'])
        coordinates.append(i['coordinates'])
        
print(coordinates)

#for i in data: 
#    print(data[i])
# Out:
# [[6.45306, 3.39583], [30.6795, -88.1033], [40.7028406, -74.0126096], [39.13333333, -84.5], [6.45306, 3.39583], [40.6383, -74.3739], [45.57416005, -122.66161141], [45.518237, -122.678249], [40.7142, -74.0064], [34.0564, -118.2445], [33.436817, -117.624764], [40.64402672, -73.93372139], [37.4441, -122.1633], [30.4365, -97.6138], [26.124354, -80.249503], [40.7142, -74.0064], [37.553836, -77.483521], [39.69944, -104.93646], [55.9426988, -3.2038346], [37.33803702, -121.88558529], [39.7391, -104.98360001], [49.69432, -112.83291], [34.1465, -118.2539], [19.0627, 72.8764], [46.6705, -90.89831], [49.69432, -112.83291], [42.48306, -83.24105], [6.6128, 3.576], [29.98468, -90.11376], [34.036681, -118.248217], [34.036681, -118.248217], [47.6040587, -122.3162431], [34.0564, -118.2445], [43.76381622, -79.49787539], [37.74699781, -122.49470016], [43.648, -79.3872], [37.917409, -122.379215], [40.21, -75.37], [33.990026, -118.461971], [52.1266, -106.6612], [17.7667, -77.25], [41.5909, -93.6209], [41.4
# ...
